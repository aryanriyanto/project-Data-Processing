# %% [markdown]
# # Preprocesing Data

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity
import pydotplus
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"C:\Users\aryan\OneDrive\Desktop\Studi Idependen MSIB 6\Data Project\Orders Detail.xlsx")
df
# Out:
#        order_details_id  order_id       pizza_id pizza_type_id category size  \
# 0                     1         1     hawaiian_m      hawaiian  Classic    M
# 1                     2         2  classic_dlx_m   classic_dlx  Classic    M
# 2                     3         2  five_cheese_l   five_cheese   Veggie    L
# 3                     4         2    ital_supr_l     ital_supr  Supreme    L
# 4                     5         2     mexicana_m      mexicana   Veggie    M
# ...                 ...       ...            ...           ...      ...  ...
# 48615             48616     21348  ckn_alfredo_m   ckn_alfredo  Chicken    M
# 48616             48617     21348  four_cheese_l   four_cheese   Veggie    L
# 48617             48618     21348   napolitana_s    napolitana  Classic    S
# 48618             48619     21349     mexicana_l      mexicana   Veggie    L
# 48619             48620     21350      bbq_ckn_s       bbq_ckn  Chicken    S
#
# ...

# %%
filtered_xl = df[df['size'].isin(['XL', 'XXL'])]
filtered_xl
# Out:
#        order_details_id  order_id      pizza_id pizza_type_id category size  \
# 121                 122        50  the_greek_xl     the_greek  Classic   XL
# 297                 298       125  the_greek_xl     the_greek  Classic   XL
# 357                 358       147  the_greek_xl     the_greek  Classic   XL
# 386                 387       161  the_greek_xl     the_greek  Classic   XL
# 469                 470       200  the_greek_xl     the_greek  Classic   XL
# ...                 ...       ...           ...           ...      ...  ...
# 48099             48100     21140  the_greek_xl     the_greek  Classic   XL
# 48220             48221     21189  the_greek_xl     the_greek  Classic   XL
# 48372             48373     21243  the_greek_xl     the_greek  Classic   XL
# 48436             48437     21270  the_greek_xl     the_greek  Classic   XL
# 48540             48541     21314  the_greek_xl     the_greek  Classic   XL
#
#        price  quantity  amount       date      time
# ...

# %%
filtered_xxl = df[df['size'].isin(['XXL'])]
filtered_xxl
# Out:
#        order_details_id  order_id       pizza_id pizza_type_id category size  \
# 3447               3448      1528  the_greek_xxl     the_greek  Classic  XXL
# 3563               3564      1581  the_greek_xxl     the_greek  Classic  XXL
# 5901               5902      2614  the_greek_xxl     the_greek  Classic  XXL
# 6365               6366      2813  the_greek_xxl     the_greek  Classic  XXL
# 7490               7491      3297  the_greek_xxl     the_greek  Classic  XXL
# 9844               9845      4307  the_greek_xxl     the_greek  Classic  XXL
# 10282             10283      4498  the_greek_xxl     the_greek  Classic  XXL
# 10875             10876      4761  the_greek_xxl     the_greek  Classic  XXL
# 13511             13512      5927  the_greek_xxl     the_greek  Classic  XXL
# 13779             13780      6038  the_greek_xxl     the_greek  Classic  XXL
# 14029             14030      6150  the_greek_xxl     the_greek  Classic  XXL
# ...

# %% [markdown]
# # Assesing data atau EDA

# %% [markdown]
# ## Order Detail

# %%
print("--Dimensi Dataframe--")
print("pada Order Details : ", df.shape)
df.info()
# Out:
# --Dimensi Dataframe--
# pada Order Details :  (48620, 11)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_details_id  48620 non-null  int64
#  1   order_id          48620 non-null  int64
#  2   pizza_id          48620 non-null  object
#  3   pizza_type_id     48620 non-null  object
#  4   category          48620 non-null  object
#  5   size              48620 non-null  object
#  6   price             48620 non-null  float64
#  7   quantity          48620 non-null  int64
#  8   amount            48620 non-null  float64
#  9   date              48620 non-null  datetime64[ns]
#  10  time              48620 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(5)
# memory usage: 4.1+ MB

# %%
print("--Statistik Deskriptif--")
print("pada Order Details : ", df.shape)
df.describe()
# Out:
# --Statistik Deskriptif--
# pada Order Details :  (48620, 11)
#        order_details_id      order_id         price      quantity  \
# count      48620.000000  48620.000000  48620.000000  48620.000000
# mean       24310.500000  10701.479761     16.494132      1.019622
# min            1.000000      1.000000      9.750000      1.000000
# 25%        12155.750000   5337.000000     12.750000      1.000000
# 50%        24310.500000  10682.500000     16.500000      1.000000
# 75%        36465.250000  16100.000000     20.250000      1.000000
# max        48620.000000  21350.000000     35.950000      4.000000
# std        14035.529381   6180.119770      3.621789      0.143077
#
#              amount                           date
# count  48620.000000                          48620
# mean      16.821474  2015-06-29 11:03:43.611682560
# min        9.750000            2015-01-01 00:00:00
# 25%       12.750000            2015-03-31 00:00:00
# 50%       16.500000            2015-06-28 00:00:00
# ...

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='size', data=df)
plt.title('Distribusi size')
plt.xlabel('size')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# ## XL

# %%
print("--Dimensi Dataframe--")
print("pada XL : ", filtered_xl.shape)
filtered_xl.info()
# Out:
# --Dimensi Dataframe--
# pada XL :  (572, 11)
# <class 'pandas.core.frame.DataFrame'>
# Index: 572 entries, 121 to 48540
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_details_id  572 non-null    int64
#  1   order_id          572 non-null    int64
#  2   pizza_id          572 non-null    object
#  3   pizza_type_id     572 non-null    object
#  4   category          572 non-null    object
#  5   size              572 non-null    object
#  6   price             572 non-null    float64
#  7   quantity          572 non-null    int64
#  8   amount            572 non-null    float64
#  9   date              572 non-null    datetime64[ns]
#  10  time              572 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(5)
# memory usage: 53.6+ KB

# %%
print("--Statistik Deskriptif--")
print("pada XL : ", filtered_xl.shape)
filtered_xl.describe()
# Out:
# --Statistik Deskriptif--
# pada XL :  (572, 11)
#        order_details_id      order_id       price    quantity      amount  \
# count        572.000000    572.000000  572.000000  572.000000  572.000000
# mean       23589.393357  10382.758741   26.011538    1.013986   26.368182
# min          122.000000     50.000000   25.500000    1.000000   25.500000
# 25%        12456.250000   5470.750000   25.500000    1.000000   25.500000
# 50%        22661.500000   9959.500000   25.500000    1.000000   25.500000
# 75%        35438.000000  15648.750000   25.500000    1.000000   25.500000
# max        48541.000000  21314.000000   35.950000    2.000000   51.000000
# std        13763.830747   6061.500255    2.256725    0.117535    3.702730
#
#                                 date
# count                            572
# mean   2015-06-24 01:10:29.370629376
# min              2015-01-01 00:00:00
# 25%              2015-04-02 00:00:00
# 50%              2015-06-16 00:00:00
# ...

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='size', data=filtered_xl)
plt.title('Distribusi size')
plt.xlabel('size')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# ## XXL

# %%
print("--Dimensi Dataframe--")
print("pada XXL : ", filtered_xxl.shape)
filtered_xxl.info()
# Out:
# --Dimensi Dataframe--
# pada XXL :  (28, 11)
# <class 'pandas.core.frame.DataFrame'>
# Index: 28 entries, 3447 to 47489
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_details_id  28 non-null     int64
#  1   order_id          28 non-null     int64
#  2   pizza_id          28 non-null     object
#  3   pizza_type_id     28 non-null     object
#  4   category          28 non-null     object
#  5   size              28 non-null     object
#  6   price             28 non-null     float64
#  7   quantity          28 non-null     int64
#  8   amount            28 non-null     float64
#  9   date              28 non-null     datetime64[ns]
#  10  time              28 non-null     object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(5)
# memory usage: 2.6+ KB

# %%
print("--Statistik Deskriptif--")
print("pada XXL : ", filtered_xxl.shape)
filtered_xxl.describe()
# Out:
# --Statistik Deskriptif--
# pada XXL :  (28, 11)
#        order_details_id      order_id         price  quantity        amount  \
# count         28.000000     28.000000  2.800000e+01      28.0  2.800000e+01
# mean       22882.250000  10073.607143  3.595000e+01       1.0  3.595000e+01
# min         3448.000000   1528.000000  3.595000e+01       1.0  3.595000e+01
# 25%        10727.750000   4695.250000  3.595000e+01       1.0  3.595000e+01
# 50%        19970.000000   8773.500000  3.595000e+01       1.0  3.595000e+01
# 75%        36155.500000  15963.000000  3.595000e+01       1.0  3.595000e+01
# max        47490.000000  20866.000000  3.595000e+01       1.0  3.595000e+01
# std        14010.486854   6175.382467  1.447163e-14       0.0  1.447163e-14
#
#                                 date
# count                             28
# mean   2015-06-18 23:08:34.285714176
# min              2015-01-26 00:00:00
# 25%              2015-03-20 00:00:00
# 50%              2015-05-27 00:00:00
# ...

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='size', data=filtered_xxl)
plt.title('Distribusi size')
plt.xlabel('size')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# # Missing Values

# %%
mvdf = df.isna().sum()

print("jumlah Missing Values : ")
print("__"*12)
print(mvdf)
# Out:
# jumlah Missing Values :
# ________________________
# order_details_id    0
# order_id            0
# pizza_id            0
# pizza_type_id       0
# category            0
# size                0
# price               0
# quantity            0
# amount              0
# date                0
# time                0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#        order_details_id  order_id       pizza_id pizza_type_id category size  \
# 0                     1         1     hawaiian_m      hawaiian  Classic    M
# 1                     2         2  classic_dlx_m   classic_dlx  Classic    M
# 2                     3         2  five_cheese_l   five_cheese   Veggie    L
# 3                     4         2    ital_supr_l     ital_supr  Supreme    L
# 4                     5         2     mexicana_m      mexicana   Veggie    M
# ...                 ...       ...            ...           ...      ...  ...
# 48615             48616     21348  ckn_alfredo_m   ckn_alfredo  Chicken    M
# 48616             48617     21348  four_cheese_l   four_cheese   Veggie    L
# 48617             48618     21348   napolitana_s    napolitana  Classic    S
# 48618             48619     21349     mexicana_l      mexicana   Veggie    L
# 48619             48620     21350      bbq_ckn_s       bbq_ckn  Chicken    S
#
# ...

# %%
duplicate_count = df.duplicated().sum()
print("Jumlah Duplikasi pada order detail: ", duplicate_count)
# Out:
# Jumlah Duplikasi pada order detail:  0

# %%
# Out:
#   Cell In[20], line 3
#     df_normalized = pd.DataFrame(scaler.fit_transform()
#                                                        ^
# SyntaxError: incomplete input

# %%
import pandas as pd

order_detail = 'order_detail.xlsx'
df.to_excel(order_detail, index=False)

# %%
import pandas as pd

filteredXXL = 'filteredXXL.xlsx'
filtered_xxl.to_excel(filteredXXL, index=False)

# %%
import pandas as pd

filteredXL = 'filteredXL.xlsx'
filtered_xl.to_excel(filteredXL, index=False)
